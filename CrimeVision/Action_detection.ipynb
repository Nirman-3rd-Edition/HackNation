# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
# Out:
# WARNING:tensorflow:From C:\Users\rohan\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
mp_holistic = mp.solutions.holistic 
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
    image.flags.writeable = False                  
    results = model.process(image)                 
    image.flags.writeable = True                   
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) 
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) 
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) 
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) 
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

# %%
def draw_styled_landmarks(image, results):
    
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
 
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        
        ret, frame = cap.read()

        
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        
        draw_styled_landmarks(image, results)

        
        cv2.imshow('OpenCV Feed', image)

        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 10
#       4 while cap.isOpened():
#       7     ret, frame = cap.read()
# ---> 10     image, results = mediapipe_detection(frame, holistic)
#      11     print(results)
#      14     draw_styled_landmarks(image, results)
#
# Cell In[4], line 4, in mediapipe_detection(image, model)
#       2 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       3 image.flags.writeable = False
# ----> 4 results = model.process(image)
#       5 image.flags.writeable = True
#       6 image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mediapipe\python\solutions\holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mediapipe\python\solution_base.py:372, in SolutionBase.process(self, input_data)
#     366   else:
#     367     self._graph.add_packet_to_input_stream(
#     368         stream=stream_name,
#     369         packet=self._make_packet(input_stream_type,
#     370                                  data).at(self._simulated_timestamp))
# --> 372 self._graph.wait_until_idle()
#     373 # Create a NamedTuple object where the field names are mapping to the graph
#     374 # output stream names.
#     375 solution_outputs = collections.namedtuple(
#     376     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
len(pose)
# Out:
# 33

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() 
    if results.face_landmarks 
    else np.zeros(1404)
# Out:
#   Cell In[14], line 2
#     if results.face_landmarks
#     ^
# IndentationError: unexpected indent

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.58509862,  0.38657045, -0.61776143, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.58509862,  0.38657045, -0.61776143, ...,  0.        ,
#         0.        ,  0.        ])

# %%
import os


DATA_PATH = 'Data'
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)
    
actions = np.array(['normal','slap', 'punch', 'straggle'])

no_sequences = 30

sequence_length = 30

start_folder = 1

# %%
import os

for action in actions: 
    
    existing_dirs = [int(d) for d in os.listdir(os.path.join(DATA_PATH, action)) if os.path.isdir(os.path.join(DATA_PATH, action, d))]
    
   
    dirmax = max(existing_dirs, default=0)
    
    
    for sequence in range(0, no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(dirmax + sequence)))
        except FileExistsError:
            pass

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    for action in actions:
        for sequence in range(start_folder, start_folder + no_sequences):
            for frame_num in range(sequence_length):
                ret, frame = cap.read()
                image, results = mediapipe_detection(frame, holistic)
                draw_styled_landmarks(image, results)
                
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)
                
                keypoints = extract_keypoints(results)
                npy_dir = os.path.join(DATA_PATH, action, str(sequence))
                os.makedirs(npy_dir, exist_ok=True)
                npy_path = os.path.join(npy_dir, str(frame_num) + '.npy')
                np.save(npy_path, keypoints)

                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break

cap.release()
cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'normal': 0, 'slap': 1, 'punch': 2, 'straggle': 3}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (120, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (120,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (120, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (6, 4)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
#LSTM NEURAL NETWORK
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
res=[.7,0.2,0.1]

# %%
actions[np.argmax(res)]
# Out:
# 'normal'

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=5000, callbacks=[tb_callback])
# Out:
# Epoch 1/5000
# 4/4 [==============================] - 3s 33ms/step - loss: 2.3059 - categorical_accuracy: 0.2018
# Epoch 2/5000
# 4/4 [==============================] - 0s 33ms/step - loss: 3.3399 - categorical_accuracy: 0.2193
# Epoch 3/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 2.4294 - categorical_accuracy: 0.2632
# Epoch 4/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.8179 - categorical_accuracy: 0.2018
# Epoch 5/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.5725 - categorical_accuracy: 0.2368
# Epoch 6/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.5036 - categorical_accuracy: 0.3333
# Epoch 7/5000
# 4/4 [==============================] - 0s 42ms/step - loss: 1.4317 - categorical_accuracy: 0.2018
# Epoch 8/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.3288 - categorical_accuracy: 0.2807
# Epoch 9/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.3092 - categorical_accuracy: 0.2895
# Epoch 10/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.2847 - categorical_accuracy: 0.3421
# Epoch 11/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.2404 - categorical_accuracy: 0.4298
# Epoch 12/5000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.1760 - categorical_accuracy: 0.4912
# Epoch 13/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.1022 - categorical_accuracy: 0.5351
# Epoch 14/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.9948 - categorical_accuracy: 0.6053
# Epoch 15/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.9667 - categorical_accuracy: 0.6316
# Epoch 16/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.7826 - categorical_accuracy: 0.6667
# Epoch 17/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.1898 - categorical_accuracy: 0.4474
# Epoch 18/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.3608 - categorical_accuracy: 0.3333
# Epoch 19/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.3507 - categorical_accuracy: 0.3421
# Epoch 20/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.3378 - categorical_accuracy: 0.4386
# Epoch 21/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.3233 - categorical_accuracy: 0.3772
# Epoch 22/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.2986 - categorical_accuracy: 0.4825
# Epoch 23/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.2527 - categorical_accuracy: 0.4474
# Epoch 24/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.3101 - categorical_accuracy: 0.4386
# Epoch 25/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.5960 - categorical_accuracy: 0.3772
# Epoch 26/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.4398 - categorical_accuracy: 0.3509
# Epoch 27/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.5202 - categorical_accuracy: 0.2632
# Epoch 28/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.4277 - categorical_accuracy: 0.3509
# Epoch 29/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.7524 - categorical_accuracy: 0.3860
# Epoch 30/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 2.0125 - categorical_accuracy: 0.3246
# Epoch 31/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.5660 - categorical_accuracy: 0.2982
# Epoch 32/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.6182 - categorical_accuracy: 0.2281
# Epoch 33/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.6495 - categorical_accuracy: 0.2895
# Epoch 34/5000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.7003 - categorical_accuracy: 0.1754
# Epoch 35/5000
# 4/4 [==============================] - 0s 40ms/step - loss: 1.4284 - categorical_accuracy: 0.3246
# Epoch 36/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.3681 - categorical_accuracy: 0.3421
# Epoch 37/5000
# 4/4 [==============================] - 0s 41ms/step - loss: 1.3569 - categorical_accuracy: 0.3246
# Epoch 38/5000
# 4/4 [==============================] - 0s 44ms/step - loss: 1.3653 - categorical_accuracy: 0.3596
# Epoch 39/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.3942 - categorical_accuracy: 0.2719
# Epoch 40/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.3346 - categorical_accuracy: 0.3772
# Epoch 41/5000
# 4/4 [==============================] - 0s 39ms/step - loss: 1.3240 - categorical_accuracy: 0.4737
# Epoch 42/5000
# 4/4 [==============================] - 0s 33ms/step - loss: 1.3042 - categorical_accuracy: 0.4298
# Epoch 43/5000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.2291 - categorical_accuracy: 0.5000
# Epoch 44/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.1847 - categorical_accuracy: 0.4649
# Epoch 45/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.0900 - categorical_accuracy: 0.5965
# Epoch 46/5000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.3179 - categorical_accuracy: 0.5965
# Epoch 47/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.5063 - categorical_accuracy: 0.3772
# Epoch 48/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.4836 - categorical_accuracy: 0.2807
# Epoch 49/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.3993 - categorical_accuracy: 0.4123
# Epoch 50/5000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.2826 - categorical_accuracy: 0.2719
# Epoch 51/5000
# 4/4 [==============================] - 0s 33ms/step - loss: 1.2641 - categorical_accuracy: 0.4474
# Epoch 52/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.2221 - categorical_accuracy: 0.5702
# Epoch 53/5000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.1969 - categorical_accuracy: 0.5263
# Epoch 54/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.1402 - categorical_accuracy: 0.5000
# Epoch 55/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.0652 - categorical_accuracy: 0.5000
# Epoch 56/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.9326 - categorical_accuracy: 0.5175
# Epoch 57/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.0504 - categorical_accuracy: 0.5175
# Epoch 58/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.2297 - categorical_accuracy: 0.4298
# Epoch 59/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.2038 - categorical_accuracy: 0.3860
# Epoch 60/5000
# 4/4 [==============================] - 0s 39ms/step - loss: 1.0786 - categorical_accuracy: 0.5351
# Epoch 61/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.9298 - categorical_accuracy: 0.6842
# Epoch 62/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.8883 - categorical_accuracy: 0.5614
# Epoch 63/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.8992 - categorical_accuracy: 0.5614
# Epoch 64/5000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.8243 - categorical_accuracy: 0.6404
# Epoch 65/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.7891 - categorical_accuracy: 0.7018
# Epoch 66/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.7664 - categorical_accuracy: 0.7018
# Epoch 67/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.7603 - categorical_accuracy: 0.6579
# Epoch 68/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.7117 - categorical_accuracy: 0.6930
# Epoch 69/5000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.8956 - categorical_accuracy: 0.5702
# Epoch 70/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.8856 - categorical_accuracy: 0.5526
# Epoch 71/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.9952 - categorical_accuracy: 0.6316
# Epoch 72/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.9049 - categorical_accuracy: 0.5526
# Epoch 73/5000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.9773 - categorical_accuracy: 0.5702
# Epoch 74/5000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.8888 - categorical_accuracy: 0.5614
# Epoch 75/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.8376 - categorical_accuracy: 0.6579
# Epoch 76/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.7673 - categorical_accuracy: 0.7105
# Epoch 77/5000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.7417 - categorical_accuracy: 0.7105
# Epoch 78/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.7080 - categorical_accuracy: 0.7281
# Epoch 79/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.6624 - categorical_accuracy: 0.7807
# Epoch 80/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.6778 - categorical_accuracy: 0.7193
# Epoch 81/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.6463 - categorical_accuracy: 0.7281
# Epoch 82/5000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.6844 - categorical_accuracy: 0.7018
# Epoch 83/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.6327 - categorical_accuracy: 0.7632
# Epoch 84/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.6225 - categorical_accuracy: 0.7719
# Epoch 85/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.7031 - categorical_accuracy: 0.7018
# Epoch 86/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.0526 - categorical_accuracy: 0.4737
# Epoch 87/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.9510 - categorical_accuracy: 0.6053
# Epoch 88/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.9014 - categorical_accuracy: 0.6140
# Epoch 89/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.8139 - categorical_accuracy: 0.6491
# Epoch 90/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.7670 - categorical_accuracy: 0.6930
# Epoch 91/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.6930 - categorical_accuracy: 0.7281
# Epoch 92/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.6574 - categorical_accuracy: 0.7456
# Epoch 93/5000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.6158 - categorical_accuracy: 0.7368
# Epoch 94/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.6044 - categorical_accuracy: 0.8070
# Epoch 95/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.5706 - categorical_accuracy: 0.7895
# Epoch 96/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.6410 - categorical_accuracy: 0.7281
# Epoch 97/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.5904 - categorical_accuracy: 0.7281
# Epoch 98/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.5906 - categorical_accuracy: 0.7807
# Epoch 99/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5439 - categorical_accuracy: 0.7807
# Epoch 100/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5157 - categorical_accuracy: 0.8158
# Epoch 101/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.5059 - categorical_accuracy: 0.8421
# Epoch 102/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5148 - categorical_accuracy: 0.7544
# Epoch 103/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.5079 - categorical_accuracy: 0.7895
# Epoch 104/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.5117 - categorical_accuracy: 0.7281
# Epoch 105/5000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5975 - categorical_accuracy: 0.7456
# Epoch 106/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.6881 - categorical_accuracy: 0.7281
# Epoch 107/5000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5907 - categorical_accuracy: 0.7719
# Epoch 108/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.6094 - categorical_accuracy: 0.7456
# Epoch 109/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5245 - categorical_accuracy: 0.8158
# Epoch 110/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4437 - categorical_accuracy: 0.8684
# Epoch 111/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.4180 - categorical_accuracy: 0.8421
# Epoch 112/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3892 - categorical_accuracy: 0.8509
# Epoch 113/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.4216 - categorical_accuracy: 0.8333
# Epoch 114/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.4687 - categorical_accuracy: 0.8421
# Epoch 115/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4567 - categorical_accuracy: 0.7895
# Epoch 116/5000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5438 - categorical_accuracy: 0.7982
# Epoch 117/5000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.4197 - categorical_accuracy: 0.7895
# Epoch 118/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.4808 - categorical_accuracy: 0.8158
# Epoch 119/5000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5137 - categorical_accuracy: 0.8070
# Epoch 120/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.4589 - categorical_accuracy: 0.8158
# Epoch 121/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.3671 - categorical_accuracy: 0.8421
# Epoch 122/5000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3240 - categorical_accuracy: 0.9211
# Epoch 123/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2720 - categorical_accuracy: 0.9035
# Epoch 124/5000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.3531 - categorical_accuracy: 0.8772
# Epoch 125/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3800 - categorical_accuracy: 0.8684
# Epoch 126/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3236 - categorical_accuracy: 0.8947
# Epoch 127/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2319 - categorical_accuracy: 0.9386
# Epoch 128/5000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2143 - categorical_accuracy: 0.9474
# Epoch 129/5000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1885 - categorical_accuracy: 0.9474
# Epoch 130/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1754 - categorical_accuracy: 0.9386
# Epoch 131/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2475 - categorical_accuracy: 0.8947
# Epoch 132/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.5985 - categorical_accuracy: 0.8158
# Epoch 133/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.5312 - categorical_accuracy: 0.8158
# Epoch 134/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.6521 - categorical_accuracy: 0.7895
# Epoch 135/5000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.4849 - categorical_accuracy: 0.8070
# Epoch 136/5000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.5679 - categorical_accuracy: 0.7368
# Epoch 137/5000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.6630 - categorical_accuracy: 0.7281
# Epoch 138/5000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.5323 - categorical_accuracy: 0.7895
# Epoch 139/5000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7049 - categorical_accuracy: 0.6250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 model.fit(X_train, y_train, epochs=5000, callbacks=[tb_callback])
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
